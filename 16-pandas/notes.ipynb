# %% [markdown]
# # Intro to Dataframes

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"],index=["x","y","z"])
print(df)
print(df.index.tolist())
print(df.info())
print(df.describe())
print(df.nunique())
print(df['A'].unique())
print(df.shape)
print(df.size)
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9
# ['x', 'y', 'z']
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes
# None
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0
# A    3
# B    3
# C    3
# dtype: int64
# [1 4 7]
# (3, 3)
# 9

# %% [markdown]
# # Loading in DataFrames from Files

# %%
import pandas as pd
coffee=pd.read_csv("./warmup-data/coffee.csv")
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results=pd.read_parquet('./warmup-data/results.parquet')
results.head()
bios=pd.read_csv('./warmup-data/bios.csv')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# # Accessing Data

# %%
print(coffee.head(10))
print(coffee.tail(7))
# by defaule they give 5 datas

coffee.sample(10) # to get random data
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 5   Wednesday       Latte          25
# 11   Saturday       Latte          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 3     Tuesday       Latte          20
# 2     Tuesday    Espresso          30
# 6    Thursday    Espresso          40
# 1      Monday       Latte          15
# 7    Thursday       Latte          30

# %%
print(coffee.head())
coffee.loc[1]
print(coffee.loc[[0,1,5]])
print(coffee.loc[1:6])
print(coffee.loc[1:8,["Coffee Type","Units Sold"]])
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25
#          Day Coffee Type  Units Sold
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
#   Coffee Type  Units Sold
# 1       Latte          15
# 2    Espresso          30
# 3       Latte          20
# 4    Espresso          35
# 5       Latte          25
# 6    Espresso          40
# 7       Latte          30
# 8    Espresso          45

# %%
coffee.iloc[1:8,[1,2]]
# Out:
#   Coffee Type  Units Sold
# 1       Latte          15
# 2    Espresso          30
# 3       Latte          20
# 4    Espresso          35
# 5       Latte          25
# 6    Espresso          40
# 7       Latte          30

# %%
#coffee.index=coffee["Day"]
#print(coffee.loc["Monday":"Tuesday"])

# %%
# Edit index
coffee.loc["Monday","Units Sold"]=30
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        30.0
# Monday        Monday       Latte        30.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0

# %%
# Specific Values
coffee.at[0,"Units Sold"]
coffee.iat[3,2]
coffee["Coffee Type"]
# Out:
# 0     Espresso
# 1        Latte
# 2     Espresso
# 3        Latte
# 4     Espresso
# 5        Latte
# 6     Espresso
# 7        Latte
# 8     Espresso
# 9        Latte
# 10    Espresso
# 11       Latte
# 12    Espresso
# 13       Latte
# Name: Coffee Type, dtype: object

# %%
# sort
coffee=pd.read_csv('./warmup-data/coffee.csv')
coffee.sort_values("Units Sold", ascending=False)
# multiple sorting criteria
coffee.sort_values(["Units Sold","Coffee Type"],ascending=False)
#making ascending and descending different
coffee.sort_values(["Units Sold","Coffee Type"],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row["Coffee Type"])
    print("\n")
# Out:
# 0
# Espresso
#
#
# 1
# Latte
#
#
# 2
# Espresso
#
#
# 3
# Latte
#
#
# 4
# Espresso
#
#
# 5
# Latte
#
#
# 6
# Espresso
#
#
# 7
# Latte
#
#
# 8
# Espresso
#
#
# 9
# Latte
#
#
# 10
# Espresso
#
#
# 11
# Latte
#
#
# 12
# Espresso
#
#
# 13
# Latte

# %% [markdown]
# # Filtering Data

# %%
bios.loc[(bios['height_cm']>215) & (bios['born_country']=='USA'),['name','height_cm']]
# Out:
#                     name  height_cm
# 5781      Tommy Burleson      223.0
# 6722    Shaquille O'Neal      216.0
# 6937      David Robinson      216.0
# 123850    Tyson Chandler      216.0

# %%
bios[bios['name'].str.contains('Billy')]
# regex
# Out:
#         athlete_id             name   born_date         born_city born_region  \
# 1177          1184      Billy Irwin  1968-05-20     Niagara Falls     Ontario
# 1202          1209   Billy Marquart  1915-02-24          Winnipeg    Manitoba
# 3226          3238       Billy Koch  1974-12-14  Rockville Centre    New York
# 3392          3404     Billy Fisher  1940-03-14               NaN         NaN
# 3496          3508     Billy Taylor  1952-09-14               NaN         NaN
# ...            ...              ...         ...               ...         ...
# 131133      133897     Billy Besson  1981-03-08               NaN         NaN
# 132053      134897   Billy Odhiambo  1993-11-07            Kisumu      Kisumu
# 140398      143906     Billy Dardis  1995-01-31               NaN         NaN
# 142231      145833  Billy Stairmand  1989-10-21          Hamilton     Waikato
# 144650      148346      Billy Major  1996-11-21         Cambridge     England
#
# ...

# %%
bios[bios['born_city'].isin(["USA","FRA"])]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios.query('born_country=="FRA"')
# Out:
#         athlete_id                   name   born_date    born_city  \
# 0                1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01       Meulan
# 2                3           Jean Borotra  1898-08-13     Biarritz
# 3                4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                6      Nicolas Chatelain  1970-01-13       Amiens
# ...            ...                    ...         ...          ...
# 144652      148348          James Clugnet  1996-12-04     Grenoble
# 145009      148720        Margaux Hackett  1999-06-02       Annecy
# 145281      149002         Elliott Baralo  1998-08-01       Annecy
# 145467      149194            Elisa Nakab  1998-05-08     Briançon
# 145498      149225         André Foussard  1899-05-19        Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...
